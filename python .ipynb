# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\99jib\OneDrive\Desktop\Python  Practice\mckinsey.csv")

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.keys
# Out:
# <bound method NDFrame.keys of           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]>

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 1701, 1702, 1703], shape=(1704,))

# %%
df.index= list(range(1,df.shape[0]+1))    # indexing start from 1
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1701     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1702     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1703     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.index= np.arange (1,df.shape[0]+1,dtype= 'float')
df
# Out:
#             country  year  population continent  life_exp     gdp_cap
# 1.0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2.0     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3.0     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4.0     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5.0     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...             ...   ...         ...       ...       ...         ...
# 1700.0     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1701.0     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1702.0     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1703.0     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1704.0     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
new_index= df.head()
new_index
# Out:
#          country  year  population continent  life_exp     gdp_cap
# 1.0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2.0  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3.0  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4.0  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5.0  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
new_index.index= ['a','b','c','d','e']
new_index
# Out:
#        country  year  population continent  life_exp     gdp_cap
# a  Afghanistan  1952     8425333      Asia    28.801  779.445314
# b  Afghanistan  1957     9240934      Asia    30.332  820.853030
# c  Afghanistan  1962    10267083      Asia    31.997  853.100710
# d  Afghanistan  1967    11537966      Asia    34.020  836.197138
# e  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.index = np.arange (1,df.shape[0]+1 , dtype = 'int')
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 1     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1701     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1702     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1703     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
ser = df["country"] 
ser.head(20)
# Out:
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# 5     Afghanistan
# 6     Afghanistan
# 7     Afghanistan
# 8     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# 12    Afghanistan
# 13        Albania
# 14        Albania
# 15        Albania
# 16        Albania
# 17        Albania
# 18        Albania
# 19        Albania
# 20        Albania
# Name: country, dtype: object

# %% [raw]
# ser=[12]

# %%
ser [5:15]  #  python slicing
# Out:
# 6     Afghanistan
# 7     Afghanistan
# 8     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# 12    Afghanistan
# 13        Albania
# 14        Albania
# 15        Albania
# Name: country, dtype: object

# %%
df.loc[1]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 1, dtype: object

# %%
df.loc[1:3]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3  Afghanistan  1962    10267083      Asia    31.997  853.100710

# %%
df.iloc[1]
# Out:
# country       Afghanistan
# year                 1957
# population        9240934
# continent            Asia
# life_exp           30.332
# gdp_cap         820.85303
# Name: 2, dtype: object

# %%
df.iloc[0:2]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %%
df.iloc[[1,11,22]]
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 1   Afghanistan  1957     9240934      Asia    30.332   820.853030
# 11  Afghanistan  2007    31889923      Asia    43.828   974.580338
# 22      Albania  2002     3508512    Europe    75.651  4604.211737

# %%
df.iloc[-1]      # Works and gives last row in dataframe
# Out:
# country         Zimbabwe
# year                2007
# population      12311143
# continent         Africa
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1703, dtype: object

# %%
temp = df.set_index("country")
temp
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...         ...       ...       ...         ...
# Zimbabwe     1987     9216418    Africa    62.351  706.157306
# Zimbabwe     1992    10704340    Africa    60.377  693.420786
# Zimbabwe     1997    11404948    Africa    46.809  792.449960
# Zimbabwe     2002    11926563    Africa    39.989  672.038623
# Zimbabwe     2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
temp.loc['Afghanistan']
# Out:
#              year  population continent  life_exp     gdp_cap
# country
# Afghanistan  1952     8425333      Asia    28.801  779.445314
# Afghanistan  1957     9240934      Asia    30.332  820.853030
# Afghanistan  1962    10267083      Asia    31.997  853.100710
# Afghanistan  1967    11537966      Asia    34.020  836.197138
# Afghanistan  1972    13079460      Asia    36.088  739.981106
# Afghanistan  1977    14880372      Asia    38.438  786.113360
# Afghanistan  1982    12881816      Asia    39.854  978.011439
# Afghanistan  1987    13867957      Asia    40.822  852.395945
# Afghanistan  1992    16317921      Asia    41.674  649.341395
# Afghanistan  1997    22227415      Asia    41.763  635.341351
# Afghanistan  2002    25268405      Asia    42.129  726.734055
# Afghanistan  2007    31889923      Asia    43.828  974.580338

# %%
df.reset_index()
# Out:
#       index      country  year  population continent  life_exp     gdp_cap
# 0         0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1         1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2         2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3         3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4         4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...     ...          ...   ...         ...       ...       ...         ...
# 1699   1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700   1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701   1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702   1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703   1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 7 columns]

# %%
 df.reset_index(drop=True)  # By using drop=True we can prevent creation of a new column
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
 df.reset_index(drop=True, inplace=True)

# %%
df.loc[4]
# Out:
# country       Afghanistan
# year                 1972
# population       13079460
# continent            Asia
# life_exp           36.088
# gdp_cap        739.981106
# Name: 4, dtype: object

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
le = df['life_exp']
le
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1703    43.487
# Name: life_exp, Length: 1704, dtype: float64

# %%
le.mean()
# Out:
# np.float64(59.474439366197174)

# %%
le.sum()
# Out:
# np.float64(101344.44467999999)

# %%
le.count()
# Out:
# np.int64(1704)

# %%
le.min()
# Out:
# np.float64(23.599)

# %%
le.max()
# Out:
# np.float64(82.603)

# %%
le.sum() / le.count()
# Out:
# np.float64(59.474439366197174)

# %% [markdown]
# # Python Practice

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"D:\material\Python pandas\Python Prc Data\pandas_practice_dataset.csv")
df
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 0        1001           39  North      Electronics   3218  1996      10.0
# 1        1002           29  North          Grocery   2241  2599      15.0
# 2        1003           15   West      Electronics   3159  1274       NaN
# 3        1004           43  South          Grocery   4648   978       5.0
# 4        1005            8  South        Furniture   3059  2086       5.0
# ..        ...          ...    ...              ...    ...   ...       ...
# 195      1196           37   East         Clothing    639   932       0.0
# 196      1197           33  South      Electronics   2879  1080       0.0
# 197      1198           42  North      Electronics   4236  1076      15.0
# 198      1199           44  South         Clothing   4935  1696      10.0
# 199      1200           24   East          Grocery   3875   968      15.0
#
#      order_date  revenue  profit
# 0    2024-01-01     3109    1113
# ...

# %%
df.head(10)     #Display first 10 rows of the dataset.
# Out:
#    order_id  customer_id region product_category  sales  cost  discount  \
# 0      1001           39  North      Electronics   3218  1996      10.0
# 1      1002           29  North          Grocery   2241  2599      15.0
# 2      1003           15   West      Electronics   3159  1274       NaN
# 3      1004           43  South          Grocery   4648   978       5.0
# 4      1005            8  South        Furniture   3059  2086       5.0
# 5      1006           21  South          Grocery   2365  2558      10.0
# 6      1007           39   East        Furniture   2579  2829      10.0
# 7      1008           19  South          Grocery   4746  2849       0.0
# 8      1009           23   East      Electronics   1735   974       NaN
# 9      1010           11   West          Grocery   1857  1631      15.0
#
#    order_date  revenue  profit
# 0  2024-01-01     3109    1113
# 1  2024-01-02     2164    -435
# 2  2024-01-03     3017    1743
# 3  2024-01-04     4519    3541
# ...

# %%
df.tail()  #Display last 5 rows.
# Out:
#      order_id  customer_id region product_category  sales  cost  discount  \
# 195      1196           37   East         Clothing    639   932       0.0
# 196      1197           33  South      Electronics   2879  1080       0.0
# 197      1198           42  North      Electronics   4236  1076      15.0
# 198      1199           44  South         Clothing   4935  1696      10.0
# 199      1200           24   East          Grocery   3875   968      15.0
#
#      order_date  revenue  profit
# 195  2024-07-14      621    -311
# 196  2024-07-15     2830    1750
# 197  2024-07-16     4202    3126
# 198  2024-07-17     4823    3127
# 199  2024-07-18     3844    2876

# %%
 df.describe()       #Show column names of the dataset.
# Out:
#           order_id  customer_id        sales         cost   discount  \
# count   200.000000   200.000000   200.000000   200.000000  160.00000
# mean   1100.500000    25.260000  2619.715000  1515.310000    7.65625
# std      57.879185    14.229716  1309.441802   906.735446    5.63351
# min    1001.000000     1.000000   214.000000    59.000000    0.00000
# 25%    1050.750000    13.000000  1451.750000   719.750000    3.75000
# 50%    1100.500000    26.000000  2859.500000  1514.500000   10.00000
# 75%    1150.250000    38.250000  3653.750000  2217.000000   15.00000
# max    1200.000000    50.000000  4949.000000  2997.000000   15.00000
#
#            revenue       profit
# count   200.000000   200.000000
# mean   2513.515000   998.205000
# std    1313.171404  1617.592082
# min      77.000000 -2718.000000
# 25%    1341.250000  -255.500000
# 50%    2741.500000   913.000000
# 75%    3574.000000  2329.000000
# max    4823.000000  4144.000000
